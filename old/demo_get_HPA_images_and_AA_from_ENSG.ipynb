# %% [markdown]
# ## Must download this tsv: https://www.proteinatlas.org/download/proteinatlas.tsv.zip

# %%
# !pip install xmltodict
# !pip install bs4
# Out:
# Requirement already satisfied: xmltodict in /opt/conda/envs/pytorch-py3.6/lib/python3.6/site-packages
# You are using pip version 9.0.1, however version 9.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#     100% |################################| 92kB 3.2MB/s ta 0:00:01
# Building wheels for collected packages: bs4
#   Running setup.py bdist_wheel for bs4 ... done
#   Stored in directory: /root/.cache/pip/wheels/84/67/d4/9e09d9d5adede2ee1c7b7e8775ba3fbb04d07c4f946f0e4f11
# Successfully built bs4
# Installing collected packages: beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.6.0 bs4-0.0.1
# You are using pip version 9.0.1, however version 9.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import requests
import shutil
import urllib.parse
import urllib.request
import pprint
import os

import pdb

def load_table(protein_atlas_tsv_file='./data/proteinatlas.tsv'):
    df = pd.read_table(protein_atlas_tsv_file)
    cols_to_keep = ['Gene', 'Antibody', 'Ensembl']
    new_cols_map = dict(zip(cols_to_keep, ['gene', 'antibodies', 'ensembl_id']))
    df = df.loc[:, cols_to_keep]
    df = df.rename(columns=new_cols_map)
    df = df.dropna()
    return df

def antibody_ids_for(ensembl_id, df):
    aids = df[df.ensembl_id==ensembl_id].antibodies
    aids = aids.values[0].split(',')
    munged_aids = []
    for aid in aids:
        aid = aid.strip()
        if aid.startswith('CAB'):
            aid = aid.split('CAB')[1]
        elif aid.startswith('HPA'):
            aid = aid.split('HPA')[1]
        else:
            raise ValueError('Unrecognized antibody type: {}'.format(aid))
        aid = aid.lstrip('0')
        munged_aids.append(aid)
        
    return munged_aids
    
def get_xml_for(ensembl_id):
    url = 'https://www.proteinatlas.org/{}.xml'.format(ensembl_id)
    req = urllib.request.Request(url)
    response = urllib.request.urlopen(req)
    xml_bin = response.read()
    xml_lines = xml_bin.decode("utf-8").split('\n')
    return xml_lines

def get_image_urls(xml_lines):
    res = []
    for line in xml_lines:
        if '<imageUrl>' in line:
            strs = line.split('<imageUrl>')
            r = strs[1].split('</imageUrl>')[0]
            if 'blue' in r:
                res.append(r)
    return res          

def get_urls_for_antibody_id(urls, a_id):
    a_id_str = str(a_id)
    res = [u.split(a_id_str+'/')[-1] for u in urls if a_id_str in u]
    return res

def channels():
    return ["blue", "green", "red", "yellow"]

def make_url(aid, plate, well, field, ch):
    base_url = "https://www.proteinatlas.org/images/{}/{}_{}_{}_{}.jpg"
    url = base_url.format(aid, plate, well, field, ch)
    return url

def download_img(url, path, debug=False):
    if debug:
        print(url)
    r = requests.get(url, stream=True)
    if r.status_code == 200:
        with open(path, 'wb') as f:
            r.raw.decode_content = True
            shutil.copyfileobj(r.raw, f)
    else:
        r.raise_for_status()

def get_plates_fields_wells_for_antibody_id(a_ids, urls):
    d = dict()
    for a in a_ids:
        d[a] = []
        urls_for_antibody = get_urls_for_antibody_id(urls, a)
        for u in urls_for_antibody:
            d_sub=dict()
            res = u.split('_')
            d_sub['plate'] = res[0]
            d_sub['well'] = res[1]
            d_sub['field'] = res[2]
            d[a].append(d_sub)
    return d

def get_plate_fields_wells_from_url(url):
    d_sub=dict()
    
    _, url = os.path.split(url)
    
    res = url.split('_')
    d_sub['plate'] = res[0]
    d_sub['well'] = res[1]
    d_sub['field'] = res[2]
    
    return d_sub


def image_url_to_channel_urls(image_url):
    #image format is:
    #<some_url>/<n1>_<n2>_<n3>_<channel>.jpg
    img_channels = channels()
    
    url_root, url_name = os.path.split(image_url)
    
    underscore_positions = [pos for pos, char in enumerate(url_name) if char == '_']
    url_name_base = url_name[0:underscore_positions[2]+1]
    
    base_url = '{}/{}{}.jpg'
    
    channel_urls = [base_url.format(url_root, url_name_base, channel) for channel in img_channels]
    
    return channel_urls

# %%
df = load_table(protein_atlas_tsv_file='./data/proteinatlas.tsv')
df.head(10)
# Out:
#        gene                                         antibodies  \
# 0    TSPAN6                                          HPA004109
# 1      TNMD                               HPA034961, HPA055634
# 2      DPM1                                          HPA051818
# 3     SCYL3                                          HPA005624
# 4  C1orf112                               HPA023778, HPA024451
# 5       FGR                                          HPA002024
# 6       CFH  CAB016385, CAB016769, HPA038922, HPA049176, HP...
# 7     FUCA2                    HPA031659, HPA031660, HPA031661
# 8      GCLC                    CAB009569, HPA036359, HPA036360
# 9      NFYA                               CAB009250, HPA050779
#
#         ensembl_id
# 0  ENSG00000000003
# 1  ENSG00000000005
# 2  ENSG00000000419
# 3  ENSG00000000457
# 4  ENSG00000000460
# 5  ENSG00000000938
# 6  ENSG00000000971
# 7  ENSG00000001036
# 8  ENSG00000001084
# 9  ENSG00000001167

# %%
e_id = "ENSG00000134057" #ensemble id for CCNB1
a_ids = antibody_ids_for(e_id, df) #antibody IDs for this gene
print(a_ids)
# Out:
# ['115', '3804', '30741', '61448']

# %%
# infer plates, wells, and fields from protein atlas for all antibodies
xml = get_xml_for(e_id)
urls = get_image_urls(xml)
d = get_plates_fields_wells_for_antibody_id(a_ids, urls)

pp = pprint.PrettyPrinter(indent=4)
pp.pprint(d)
# Out:
# {   '115': [   {'field': '1', 'plate': '672', 'well': 'E2'},
#                {'field': '2', 'plate': '672', 'well': 'E2'},
#                {'field': '1', 'plate': '663', 'well': 'E2'},
#                {'field': '5', 'plate': '663', 'well': 'E2'},
#                {'field': '1', 'plate': '646', 'well': 'E2'},
#                {'field': '2', 'plate': '646', 'well': 'E2'}],
#     '30741': [   {'field': '1', 'plate': '800', 'well': 'A6'},
#                  {'field': '2', 'plate': '800', 'well': 'A6'},
#                  {'field': '1', 'plate': '845', 'well': 'A6'},
#                  {'field': '3', 'plate': '845', 'well': 'A6'},
#                  {'field': '1', 'plate': '793', 'well': 'A6'},
#                  {'field': '2', 'plate': '793', 'well': 'A6'},
#                  {'field': '1', 'plate': '686', 'well': 'F11'},
#                  {'field': '2', 'plate': '686', 'well': 'F11'},
#                  {'field': '2', 'plate': 'si28', 'well': 'H2'},
#                  {'field': '3', 'plate': 'si28', 'well': 'H2'},
#                  {'field': '13', 'plate': 'si28', 'well': 'H2'},
#                  {'field': '2', 'plate': 'si28', 'well': 'H3'},
#                  {'field': '3', 'plate': 'si28', 'well': 'H3'},
#                  {'field': '12', 'plate': 'si28', 'well': 'H3'},
#                  {'field': '1', 'plate': '200', 'well': '382'},
#                  {'field': '1', 'plate': '200', 'well': '383'}],
#     '3804': [],
#     '61448': [   {'field': '2', 'plate': '1319', 'well': 'C10'},
#                  {'field': '8', 'plate': '1319', 'well': 'C10'},
#                  {'field': '1', 'plate': '1080', 'well': 'B1'},
#                  {'field': '2', 'plate': '1080', 'well': 'B1'},
#                  {'field': '2', 'plate': '1671', 'well': 'B6'},
#                  {'field': '5', 'plate': '1671', 'well': 'B6'},
#                  {'field': '1', 'plate': 'fp7', 'well': 'G4'},
#                  {'field': '2', 'plate': 'fp7', 'well': 'G4'},
#                  {'field': '2', 'plate': 'fp7', 'well': 'D4'},
#                  {'field': '3', 'plate': 'fp7', 'well': 'D4'}]}

# %%
# urls

# url = 'http://v18.proteinatlas.org/images/30741/si28_H2_2_red.jpg'
# r = requests.get(url)
# if(r.status_code==200):
#     print(url)

# xml
# Out:
# ['<?xml version="1.0" encoding="UTF-8"?>',
#  '<proteinAtlas xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://v18.proteinatlas.org/download/proteinatlas.xsd" schemaVersion="2.5">',
#  '\t<entry version="18" url="http://v18.proteinatlas.org/ENSG00000134057">',
#  '\t\t<name>CCNB1</name>',
#  '\t\t<synonym>CCNB</synonym>',
#  '\t\t<identifier id="ENSG00000134057" db="Ensembl" version="88.38">',
#  '\t\t\t<xref id="P14635" db="Uniprot/SWISSPROT"/>',
#  '\t\t</identifier>',
#  '\t\t<proteinClasses>',
#  '\t\t\t<proteinClass source="TCDB" id="Ja" parent_id="" name="Transporters"/>',
#  '\t\t\t<proteinClass source="TCDB" id="Jb" parent_id="Ja" name="Transporter channels and pores"/>',
#  '\t\t\t<proteinClass source="SPOCTOPUS" id="Mi" parent_id="" name="SPOCTOPUS predicted membrane proteins"/>',
#  '\t\t\t<proteinClass source="HPA" id="Za" parent_id="" name="Predicted intracellular proteins"/>',
#  '\t\t\t<proteinClass source="Plasma Proteome Database" id="Pp" parent_id="" name="Plasma proteins"/>',
#  '\t\t\t<proteinClass source="" id="Ca" parent_id="" name="Cancer-related genes"/>',
#  '\t\t\t<proteinClass source="Plasma Proteome Institute" id="Cb" parent_id="Ca" name="Candidate cancer biomarkers"/>',
#  '\t\t\t<proteinClass source="UniProt" id="Ua" parent_id="" name="UniProt - Evidence at protein level"/>',
#  '\t\t\t<proteinClass source="Kim et al 2014" id="Ea" parent_id="" name="Protein evidence (Kim et al 2014)"/>',
#  '\t\t\t<proteinClass source="Ezkurdia et al 2014" id="Eb" parent_id="" name="Protein evidence (Ezkurdia et al 2014)"/>',
#  '\t\t</proteinClasses>',
#  '\t\t<proteinEvidence evidence="Evidence at protein level">',
#  '\t\t\t<evidence source="HPA" evidence="Evidence at protein level"/>',
#  '\t\t\t<evidence source="MS" evidence="Evidence at protein level"/>',
#  '\t\t\t<evidence source="UniProt" evidence="Evidence at protein level"/>',
#  '\t\t</proteinEvidence>',
#  '\t\t<tissueExpression source="HPA" technology="IHC" assayType="tissue">',
#  '\t\t\t<summary type="tissue"><![CDATA[Cytoplasmic expression in proliferating cells.]]></summary>',
#  '\t\t\t<verification type="reliability" description="Antibody staining mainly consistent with RNA expression data. ">enhanced</verification>',
#  '\t\t\t<image imageType="selected">',
#  '\t\t\t\t<tissue>cerebral cortex</tissue>',
#  '\t\t\t\t<imageUrl>http://v18.proteinatlas.org/images/3804/10580_B_8_5_rna_selected.jpg</imageUrl>',
#  '\t\t\t',
#  '\t\t\t<image imageType="selected">',
#  '\t\t\t\t<tissue>lymph node</tissue>',
#  '\t\t\t\t<imageUrl>http://v18.proteinatlas.org/images/3804/10580_A_8_8_rna_selected.jpg</imageUrl>',
#  '\t\t\t',
#  '\t\t\t<image imageType="selected">',
#  '\t\t\t\t<tissue>liver</tissue>',
#  '\t\t\t\t<imageUrl>http://v18.proteinatlas.org/images/3804/10580_A_7_4_rna_selected.jpg</imageUrl>',
#  '\t\t\t',
#  '\t\t\t<image imageType="selected">',
#  '\t\t\t\t<tissue>colon</tissue>',
#  '\t\t\t\t<imageUrl>http://v18.proteinatlas.org/images/3804/10580_A_9_3_rna_selected.jpg</imageUrl>',
#  '\t\t\t',
#  '\t\t\t<image imageType="selected">',
#  '\t\t\t\t<tissue>kidney</tissue>',
#  '\t\t\t\t<imageUrl>http://v18.proteinatlas.org/images/3804/10580_A_9_5_rna_selected.jpg</imageUrl>',
#  '\t\t\t',
#  '\t\t\t<image imageType="selected">',
#  '\t\t\t\t<tissue>testis</tissue>',
#  '\t\t\t\t<imageUrl>http://v18.proteinatlas.org/images/3804/10580_A_4_6_rna_selected.jpg</imageUrl>',
#  '\t\t\t',
#  '\t\t\t<image imageType="selected">',
#  '\t\t\t\t<tissue>placenta</tissue>',
#  '\t\t\t\t<imageUrl>http://v18.proteinatlas.org/images/3804/10580_A_2_7_rna_selected.jpg</imageUrl>',
#  '\t\t\t',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>adrenal gland</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>appendix</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>lymphoid tissue</cellType>',
#  '\t\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>bone marrow</tissue>',
#  '\t\t\t\t<level type="expression">high</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>hematopoietic cells</cellType>',
#  '\t\t\t\t\t<level type="expression">high</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>breast</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>adipocytes</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>myoepithelial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>bronchus</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>respiratory epithelial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>caudate</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>neuronal cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>cerebellum</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>cells in granular layer</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>cells in molecular layer</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>Purkinje cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>cerebral cortex</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>endothelial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>neuronal cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>neuropil</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>cervix, uterine</tissue>',
#  '\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>squamous epithelial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>colon</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>endothelial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>peripheral nerve/ganglion</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>duodenum</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>endometrium</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>cells in endometrial stroma</cellType>',
#  '\t\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>endometrium</tissue>',
#  '\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>cells in endometrial stroma</cellType>',
#  '\t\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>epididymis</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>esophagus</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>squamous epithelial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>fallopian tube</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>gallbladder</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>heart muscle</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>myocytes</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>hippocampus</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>neuronal cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>kidney</tissue>',
#  '\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>cells in glomeruli</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>cells in tubules</cellType>',
#  '\t\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>liver</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>bile duct cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>hepatocytes</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>lung</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>macrophages</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>pneumocytes</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>lymph node</tissue>',
#  '\t\t\t\t<level type="expression">high</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>germinal center cells</cellType>',
#  '\t\t\t\t\t<level type="expression">high</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>non-germinal center cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>nasopharynx</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>respiratory epithelial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>oral mucosa</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>squamous epithelial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>ovary</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>follicle cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>ovarian stroma cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>pancreas</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>exocrine glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>islets of Langerhans</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>parathyroid gland</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>placenta</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>decidual cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>trophoblastic cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>prostate</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>rectum</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>salivary gland</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>seminal vesicle</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>skeletal muscle</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>myocytes</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>skin</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>fibroblasts</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>keratinocytes</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>Langerhans</cellType>',
#  '\t\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>melanocytes</cellType>',
#  '\t\t\t\t\t<level type="expression">low</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>skin</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>epidermal cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>small intestine</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>smooth muscle</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>smooth muscle cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>soft tissue</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>adipocytes</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>chondrocytes</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>fibroblasts</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>peripheral nerve</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>soft tissue</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>adipocytes</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>fibroblasts</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>peripheral nerve</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>spleen</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>cells in red pulp</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>cells in white pulp</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>stomach</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>stomach</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>testis</tissue>',
#  '\t\t\t\t<level type="expression">high</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>cells in seminiferous ducts</cellType>',
#  '\t\t\t\t\t<level type="expression">high</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>Leydig cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>thyroid gland</tissue>',
#  '\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>glandular cells</cellType>',
#  '\t\t\t\t\t<level type="expression">not detected</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>tonsil</tissue>',
#  '\t\t\t\t<level type="expression">high</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>germinal center cells</cellType>',
#  '\t\t\t\t\t<level type="expression">high</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>non-germinal center cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>squamous epithelial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>urinary bladder</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>urothelial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>vagina</tissue>',
#  '\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t<tissueCell>',
#  '\t\t\t\t\t<cellType>squamous epithelial cells</cellType>',
#  '\t\t\t\t\t<level type="expression">medium</level>',
#  '\t\t\t\t</tissueCell>',
#  '\t\t\t</data>',
#  '\t\t</tissueExpression>',
#  '\t\t<cellExpression source="HPA" technology="ICC/IF">',
#  '\t\t\t<summary><![CDATA[Localized to the cytosol.]]></summary>',
#  '\t\t\t<verification type="reliability">enhanced</verification>',
#  '\t\t\t<image imageType="selected">',
#  '\t\t\t\t<imageUrl>http://v18.proteinatlas.org/images/30741/793_A6_1_selected.jpg</imageUrl>',
#  '\t\t\t',
#  '\t\t\t<data>',
#  '\t\t\t\t<location status="main" GOId="GO:0005829">cytosol</location>',
#  '\t\t\t</data>',
#  '\t\t</cellExpression>',
#  '\t\t<rnaExpression source="HPA" technology="RNAseq">',
#  '\t\t\t<rnaTissueCategory description="Detected in 2-37 tissues but not elevated in any tissue">Mixed</rnaTissueCategory>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>A-431</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="407.3">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>A549</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="286.1">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>AF22</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="418.9">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>AN3-CA</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="352.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>ASC diff</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="15.1">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>ASC TERT1</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="25.8">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>BEWO</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="963.9">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>BJ</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="170.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>BJ hTERT+</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="122.0">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>BJ hTERT+ SV40 Large T+</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="483.8">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>BJ hTERT+ SV40 Large T+ RasG12V</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="424.7">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>CACO-2</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="389.0">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>CAPAN-2</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="375.5">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>Daudi</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="203.5">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>EFO-21</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="225.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>fHDF/TERT166</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="145.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HaCaT</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="253.3">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HAP1</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="444.7">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HBEC3-KT</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="315.8">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HBF TERT88</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="559.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HDLM-2</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="261.0">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HEK 293</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="195.7">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HEL</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="162.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HeLa</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="175.9">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>Hep G2</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="223.0">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HHSteC</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="5.7">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HL-60</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="126.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HMC-1</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="174.5">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HSkMC</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="12.0">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>hTCEpi</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="19.8">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>hTEC/SVTERT24-B</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="299.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>hTERT-HME1</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="158.7">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>HUVEC TERT2</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="234.9">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>K-562</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="199.0">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>Karpas-707</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="157.8">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>LHCN-M2</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="357.8">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>MCF7</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="338.7">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>MOLT-4</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="175.7">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>NB-4</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="119.3">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>NTERA-2</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="236.9">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>PC-3</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="183.7">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>REH</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="207.6">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>RH-30</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="296.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>RPMI-8226</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="203.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>RPTEC TERT1</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="144.4">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>RT4</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="135.1">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>SCLC-21H</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="253.3">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>SH-SY5Y</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="143.6">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>SiHa</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="367.9">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>SK-BR-3</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="120.6">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>SK-MEL-30</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="117.3">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>T-47d</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="289.7">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>THP-1</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="110.6">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>TIME</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="97.4">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>U-138 MG</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="113.6">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>U-2 OS</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="390.1">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>U-2197</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="195.3">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>U-251 MG</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="422.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>U-266/70</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="83.4">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>U-266/84</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="151.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>U-698</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="272.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>U-87 MG</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="156.2">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>U-937</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="214.8">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<cellLine>WM-115</cellLine>',
#  '\t\t\t\t<level type="abundance" tpm="356.9">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>adipose tissue</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="4.5">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>adrenal gland</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="5.1">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>appendix</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="34.9">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>bone marrow</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="32.7">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>breast</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="11.8">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>cerebral cortex</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="7.7">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>cervix, uterine</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="8.9">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>colon</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="22.0">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>duodenum</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="21.0">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>endometrium 1</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="13.3">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>epididymis</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="6.5">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>esophagus</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="25.5">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>fallopian tube</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="12.2">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>gallbladder</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="6.0">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>heart muscle</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="1.8">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>kidney</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="5.1">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>liver</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="2.2">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>lung</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="5.5">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>lymph node</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="65.5">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>ovary</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="5.5">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>pancreas</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="0.7">Not detected</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>parathyroid gland</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="6.1">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>placenta</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="30.0">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>prostate</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="5.9">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>rectum</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="33.3">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>salivary gland</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="1.7">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>seminal vesicle</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="5.3">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>skeletal muscle</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="1.1">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>skin 1</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="17.3">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>small intestine</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="22.0">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>smooth muscle</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="20.8">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>spleen</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="9.9">Low</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>stomach 1</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="10.2">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>testis</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="60.0">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>thyroid gland</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="14.3">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>tonsil</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="62.1">High</level>',
#  '\t\t\t</data>',
#  '\t\t\t<data>',
#  '\t\t\t\t<tissue>urinary bladder</tissue>',
#  '\t\t\t\t<level type="abundance" tpm="14.3">Medium</level>',
#  '\t\t\t</data>',
#  '\t\t</rnaExpression>',
#  '\t\t<antibody id="CAB000115" releaseVersion="1.2" releaseDate="2006-03-13">',
#  '\t\t\t<antigenSequence></antigenSequence>',
#  '\t\t\t<antibodyTargetWeights>',
#  '\t\t\t\t<weight value="48.3" unit="kDa"/>',
#  '\t\t\t\t<weight value="44.9" unit="kDa"/>',
#  '\t\t\t\t<weight value="44.1" unit="kDa"/>',
#  ...]

# %% [markdown]
# ## Print out downloadable urls for this gene

# %%
# look for single channel images for gene: ENSG00000134057 = CCNB1
for a_id in a_ids:
    for pwf in d[a_id]:
        for ch in ['red', 'blue', 'green', 'yellow']:
            url = make_url(a_id, pwf['plate'], pwf['well'], pwf['field'], ch=ch)
            r = requests.get(url)
            if(r.status_code==200):
                print(url)

# %%
def ensg2dataframe(e_id):
        # infer plates, wells, and fields from protein atlas for all antibodies
    xml = get_xml_for(e_id)
    urls = get_image_urls(xml)
    d = get_plates_fields_wells_for_antibody_id(a_ids, urls)

    pdb.set_trace()

# %%
ensg2dataframe()
# Out:
# --Return--
# > <ipython-input-19-95e8cc81349d>(7)ensg2dataframe()->None
# -> pdb.set_trace()
# (Pdb) urls
# ['http://v18.proteinatlas.org/images/115/672_E2_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/115/672_E2_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/115/663_E2_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/115/663_E2_5_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/115/646_E2_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/115/646_E2_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/800_A6_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/800_A6_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/845_A6_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/845_A6_3_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/793_A6_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/793_A6_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/686_F11_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/686_F11_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H2_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H2_3_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H2_13_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H3_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H3_3_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H3_12_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/200_382_1_blue_green_red_yellow.jpg', 'http://v18.proteinatlas.org/images/30741/200_383_1_blue_green_red_yellow.jpg', 'http://v18.proteinatlas.org/images/61448/1319_C10_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/1319_C10_8_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/1080_B1_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/1080_B1_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/1671_B6_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/1671_B6_5_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/fp7_G4_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/fp7_G4_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/fp7_D4_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/fp7_D4_3_blue_red_green.jpg']
# (Pdb) print(urls)
# ['http://v18.proteinatlas.org/images/115/672_E2_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/115/672_E2_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/115/663_E2_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/115/663_E2_5_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/115/646_E2_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/115/646_E2_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/800_A6_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/800_A6_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/845_A6_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/845_A6_3_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/793_A6_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/793_A6_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/686_F11_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/686_F11_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H2_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H2_3_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H2_13_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H3_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H3_3_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/si28_H3_12_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/30741/200_382_1_blue_green_red_yellow.jpg', 'http://v18.proteinatlas.org/images/30741/200_383_1_blue_green_red_yellow.jpg', 'http://v18.proteinatlas.org/images/61448/1319_C10_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/1319_C10_8_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/1080_B1_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/1080_B1_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/1671_B6_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/1671_B6_5_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/fp7_G4_1_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/fp7_G4_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/fp7_D4_2_blue_red_green.jpg', 'http://v18.proteinatlas.org/images/61448/fp7_D4_3_blue_red_green.jpg']
# (Pdb) for url in urls: print(url)
# http://v18.proteinatlas.org/images/115/672_E2_1_blue_red_green.jpg
# http://v18.proteinatlas.org/images/115/672_E2_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/115/663_E2_1_blue_red_green.jpg
# http://v18.proteinatlas.org/images/115/663_E2_5_blue_red_green.jpg
# http://v18.proteinatlas.org/images/115/646_E2_1_blue_red_green.jpg
# http://v18.proteinatlas.org/images/115/646_E2_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/800_A6_1_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/800_A6_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/845_A6_1_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/845_A6_3_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/793_A6_1_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/793_A6_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/686_F11_1_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/686_F11_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/si28_H2_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/si28_H2_3_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/si28_H2_13_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/si28_H3_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/si28_H3_3_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/si28_H3_12_blue_red_green.jpg
# http://v18.proteinatlas.org/images/30741/200_382_1_blue_green_red_yellow.jpg
# http://v18.proteinatlas.org/images/30741/200_383_1_blue_green_red_yellow.jpg
# http://v18.proteinatlas.org/images/61448/1319_C10_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/61448/1319_C10_8_blue_red_green.jpg
# http://v18.proteinatlas.org/images/61448/1080_B1_1_blue_red_green.jpg
# http://v18.proteinatlas.org/images/61448/1080_B1_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/61448/1671_B6_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/61448/1671_B6_5_blue_red_green.jpg
# http://v18.proteinatlas.org/images/61448/fp7_G4_1_blue_red_green.jpg
# http://v18.proteinatlas.org/images/61448/fp7_G4_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/61448/fp7_D4_2_blue_red_green.jpg
# http://v18.proteinatlas.org/images/61448/fp7_D4_3_blue_red_green.jpg
# (Pdb) d
# *** Newest frame
# (Pdb) d
# *** Newest frame
# (Pdb) get_plates_fields_wells_for_antibody_id(a_ids, urls)
# {'115': [{'plate': '672', 'well': 'E2', 'field': '1'}, {'plate': '672', 'well': 'E2', 'field': '2'}, {'plate': '663', 'well': 'E2', 'field': '1'}, {'plate': '663', 'well': 'E2', 'field': '5'}, {'plate': '646', 'well': 'E2', 'field': '1'}, {'plate': '646', 'well': 'E2', 'field': '2'}], '3804': [], '30741': [{'plate': '800', 'well': 'A6', 'field': '1'}, {'plate': '800', 'well': 'A6', 'field': '2'}, {'plate': '845', 'well': 'A6', 'field': '1'}, {'plate': '845', 'well': 'A6', 'field': '3'}, {'plate': '793', 'well': 'A6', 'field': '1'}, {'plate': '793', 'well': 'A6', 'field': '2'}, {'plate': '686', 'well': 'F11', 'field': '1'}, {'plate': '686', 'well': 'F11', 'field': '2'}, {'plate': 'si28', 'well': 'H2', 'field': '2'}, {'plate': 'si28', 'well': 'H2', 'field': '3'}, {'plate': 'si28', 'well': 'H2', 'field': '13'}, {'plate': 'si28', 'well': 'H3', 'field': '2'}, {'plate': 'si28', 'well': 'H3', 'field': '3'}, {'plate': 'si28', 'well': 'H3', 'field': '12'}, {'plate': '200', 'well': '382', 'field': '1'}, {'plate': '200', 'well': '383', 'field': '1'}], '61448': [{'plate': '1319', 'well': 'C10', 'field': '2'}, {'plate': '1319', 'well': 'C10', 'field': '8'}, {'plate': '1080', 'well': 'B1', 'field': '1'}, {'plate': '1080', 'well': 'B1', 'field': '2'}, {'plate': '1671', 'well': 'B6', 'field': '2'}, {'plate': '1671', 'well': 'B6', 'field': '5'}, {'plate': 'fp7', 'well': 'G4', 'field': '1'}, {'plate': 'fp7', 'well': 'G4', 'field': '2'}, {'plate': 'fp7', 'well': 'D4', 'field': '2'}, {'plate': 'fp7', 'well': 'D4', 'field': '3'}]}
# (Pdb) exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-20-1bbf2f901593> in <module>()
# ----> 1 ensg2dataframe('ENSG00000134057')
#
# <ipython-input-19-95e8cc81349d> in ensg2dataframe(e_id)
#       5     d = get_plates_fields_wells_for_antibody_id(a_ids, urls)
#       6
# ----> 7     pdb.set_trace()
#       8
#       9
#
# /opt/conda/envs/pytorch-py3.6/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      50             return self.dispatch_call(frame, arg)
#      51         if event == 'return':
# ---> 52             return self.dispatch_return(frame, arg)
#      53         if event == 'exception':
#      54             return self.dispatch_exception(frame, arg)
#
# /opt/conda/envs/pytorch-py3.6/lib/python3.6/bdb.py in dispatch_return(self, frame, arg)
#      94             finally:
#      95                 self.frame_returning = None
# ---> 96             if self.quitting: raise BdbQuit
#      97             # The user issued a 'next' or 'until' command.
#      98             if self.stopframe is frame and self.stoplineno != -1:
#
# BdbQuit:

# %%
import xmltodict



url = 'https://www.proteinatlas.org/{}.xml'.format(e_id)
req = urllib.request.Request(url)
response = urllib.request.urlopen(req)
xml_bin = response.read()

xml_dict = xmltodict.parse(xml_bin)

# %%
for antibody in xml_dict['proteinAtlas']['entry']['antibody']:
    
    antibody_id = antibody['@id']
    
    for if_data in antibody['cellExpression']['subAssay']['data']:
        
        
        cell_line = if_data['cellLine']
        location = if_data['location']['#text']
        
        for image in if_data['assayImage']['image']:
            
            image_url = image['imageUrl']
            
            channel_urls = image_url_to_channel_urls(image_url)
            pdb.set_trace()
            
#     antibody.id
# Out:
# > <ipython-input-31-3091c1c6dccf>(11)<module>()
# -> for image in if_data['assayImage']['image']:
# (Pdb) get_plate_field_well_from_url(image_url)
# {'plate': 'http://v18.proteinatlas.org/images/115/672', 'well': 'E2', 'field': '1'}
# (Pdb) exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-31-3091c1c6dccf> in <module>()
#       9         location = if_data['location']['#text']
#      10
# ---> 11         for image in if_data['assayImage']['image']:
#      12
#      13             image_url = image['imageUrl']
#
# <ipython-input-31-3091c1c6dccf> in <module>()
#       9         location = if_data['location']['#text']
#      10
# ---> 11         for image in if_data['assayImage']['image']:
#      12
#      13             image_url = image['imageUrl']
#
# /opt/conda/envs/pytorch-py3.6/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      46             return # None
#      47         if event == 'line':
# ---> 48             return self.dispatch_line(frame)
#      49         if event == 'call':
#      50             return self.dispatch_call(frame, arg)
#
# /opt/conda/envs/pytorch-py3.6/lib/python3.6/bdb.py in dispatch_line(self, frame)
#      65         if self.stop_here(frame) or self.break_here(frame):
#      66             self.user_line(frame)
# ---> 67             if self.quitting: raise BdbQuit
#      68         return self.trace_dispatch
#      69
#
# BdbQuit:

# %%
antibody_id = 'CAB000115'

# %%
import urllib.parse
import urllib.request
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-d9389a6a9952> in <module>()
# ----> 1 import libraries
#       2 import urllib.parse
#       3 import urllib.request
#       4 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'libraries'

# %%
e_id = 'ENSG00000134057'

url = 'https://www.proteinatlas.org/{}/antibody'.format(e_id)

req = urllib.request.Request(url)
response = urllib.request.urlopen(req)
html_bin = response.read()
soup = BeautifulSoup(html_bin, 'html.parser')

# %%
souplets = soup.find_all('th', attrs={'class':'head last roundtop'})

antibody_ids = list()

for souplet in souplets:
    antibody_ids += [re.findall('>Antibody [A-Za-z0-9]*<', str(souplet))[0][10:-1]]


# import re
# re.findall('map name=\"[A-Za-z0-9]*"', str(souplet[1]))

# %%
import numpy as np

id_index = np.where([id == antibody_id for id in antibody_ids])[0][0]
# Out:
# 2

# %%
import re
re.findall('map name=\"[A-Za-z0-9]*"', str(souplet[1]))
# Out:
# ['map name="ENSP00000256442"',
#  'map name="ENSP00000424588"',
#  'map name="ENSP00000423387"',
#  'map name="ENSP00000426092"']

# %%
import numpy as np

def antibody_and_html_to_ensp(antibody_id, antibody_html_bin):
    antibody_html_str = str(antibody_html_bin)
    
    soup = BeautifulSoup(antibody_html_bin, 'html.parser')
    
    souplets = soup.find_all('th', attrs={'class':'head last roundtop'})

    antibody_ids = list()

    for souplet in souplets:
        antibody_ids += [re.findall('>Antibody [A-Za-z0-9]*<', str(souplet))[0][10:-1]]

    id_index = np.where([id == antibody_id for id in antibody_ids])[0][0]
    
    start_ind = antibody_html_str.find('Matching transcripts')
    end_ind = antibody_html_str.find('<th class="sub_head"', start_ind)
    
    split = antibody_html_str[start_ind:end_ind].split('<td class="" style="">')[id_index+1]
    
    ensp_soup = BeautifulSoup(split, 'html.parser')
    
    souplets = ensp_soup.find_all('a', attrs={'rel': 'nofollow noopener'})
    
    protein_ids = list()
    for souplet in souplets:
        protein_ids += [re.findall('ENSP[A-Za-z0-9]* ', str(souplet))[0][:-1]]
        
    return protein_ids

# %%
antibody_ids = 'HPA030741', 'HPA061448', 'CAB000115', 'CAB003804'

for antibody_id in antibody_ids:
    ensp_list = antibody_and_html_to_ensp(antibody_id, html_bin)
    print(ensp_list)
# Out:
# ['ENSP00000256442', 'ENSP00000424588', 'ENSP00000423387', 'ENSP00000426092']
# ['ENSP00000256442', 'ENSP00000424588', 'ENSP00000423387', 'ENSP00000426092']
# []
# []

# %%
e_id = 'ENSG00000126602'

url = 'https://www.proteinatlas.org/{}/antibody'.format(e_id)

req = urllib.request.Request(url)
response = urllib.request.urlopen(req)
html_bin = response.read()

antibody_ids = 'HPA041082', 'HPA044227'

for antibody_id in antibody_ids:
    ensp_list = antibody_and_html_to_ensp(antibody_id, html_bin)
    print(ensp_list)
# Out:
# ['ENSP00000246957', 'ENSP00000442070', 'ENSP00000458166']
# ['ENSP00000246957']
